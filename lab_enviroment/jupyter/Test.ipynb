# %%
# %run test.py
# Out:
#                                                  gui                CLI  \
# 0                            net.sf.jabref.JabRefGUI  net.sf.jabref.cli
# 1                           net.sf.jabref.JabRefMain                NaN
# 2                        net.sf.jabref.collab.Change                NaN
# 3           net.sf.jabref.collab.ChangeDisplayDialog                NaN
# 4                 net.sf.jabref.collab.ChangeScanner                NaN
# 5                net.sf.jabref.collab.EntryAddChange                NaN
# 6                   net.sf.jabref.collab.EntryChange                NaN
# 7             net.sf.jabref.collab.EntryDeleteChange                NaN
# 8               net.sf.jabref.collab.FileUpdatePanel                NaN
# 9                   net.sf.jabref.collab.GroupChange                NaN
# 10                     net.sf.jabref.collab.InfoPane                NaN
# 11               net.sf.jabref.collab.MetaDataChange                NaN
# ...
